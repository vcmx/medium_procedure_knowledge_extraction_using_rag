# %%
# !pip install deepeval
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.0/547.0 kB 8.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.4/243.4 kB 16.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.8/65.8 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.7/55.7 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.4/118.4 kB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.2/196.2 kB 10.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.1/89.1 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 35.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.1/46.1 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.6/40.6 kB 2.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.1.2
# ...

# %%
from google.colab import userdata
import os

from IPython import get_ipython
from IPython.display import display
# Set the API key as an environment variable
os.environ['OPENAI_API_KEY'] = userdata.get('openai')

# %% [markdown]
# Run one of the following test sets.

# %%
#test set 1: from GM engine
#result original: [0.688, 0.871, 0.813, 0.843, 0.976]
#result improved: [0.932, 0.858, 0.935, 0.911, 0.995]
input="""provide the procedure for installation and removal of spark plugs"""
output="""
Spark Plug Replacement Guide for Novice Users
Tools Required
J 39358 Spark Plug Socket

Spark Plug Removal Procedure
Step-by-Step Instructions
Warning: Allow the engine to cool before removing the spark plugs. Attempting to remove the plugs from a hot engine may cause the plug to seize, causing damage to the cylinder head threads.

Warning: Clean the spark plug recess area before removing the plug. Failure to do so can result in engine damage due to dirt or foreign material entering the cylinder head or contamination of the cylinder head threads.

Turn OFF the ignition switch completely.

Disconnect the negative battery cable from the battery terminal.

Remove the spark plug wires and boots using the following method:

Twist each boot one-half turn before removing it

Pull on the spark plug boot only - do not pull on the spark plug wire or the wire could be damaged

Label the plug wires if the identification numbers have worn off

Warning: Do not use pliers or other tools that may tear the boot when removing.

Warning: Do not force anything between the wire and the boot, or through the silicone jacket of the wiring.

Checkpoint: Verify that spark plug wires are numbered to assist in re-assembly or that you have labeled them properly.

Remove the spark plugs using the J 39358 spark plug socket.

Warning: Use the J 39358 or the equivalent. Failure to do so could cause cracking of the insulator and arcing inside the plug, resulting in engine misfire.

Inspect each plug for wear and gap according to visual diagnosis specifications.

Checkpoint: Look for signs of wear, damage, or incorrect gap spacing on each spark plug.

Spark Plug Installation Procedure
Step-by-Step Instructions
Warning: Be sure plug threads smoothly into cylinder head and is fully seated. Use a thread chaser if necessary to clean threads in cylinder head. Cross-threading or failing to fully seat spark plug can cause overheating of plug, exhaust blow-by, or thread damage.

Warning: Do not install the plugs that are either hotter or colder than the heat range specified. Using plugs of the wrong heat range may damage the engine.

Install the spark plugs by threading them smoothly into the cylinder head.

Checkpoint: Ensure each plug threads smoothly without resistance and is fully seated.

Tighten the spark plugs to 15 N- m (11 lb ft) using the J 39358 spark plug socket.

Warning: Follow the recommended torque specifications carefully. Over or under-tightening can cause severe damage to engine or spark plug.

Checkpoint: Verify torque specification of 15 N- m (11 lb ft) is achieved on each spark plug.

Install the wire and boot assemblies in their original locations using the following method:

Ensure the metal terminal within the boot is fully seated on the spark plug terminal

Check that the boot has not moved on the wire

Push sideways on the boots to verify proper installation - a stiff boot with only slight looseness indicates correct installation

Checkpoint: Push sideways on each boot - if correctly installed, you should feel a stiff boot with only slight looseness. If the terminal has not been properly seated, only the resistance of the rubber boot will be felt.

Route the wires in their original positions exactly as they were before removal.

Warning: Wire routings must be kept intact during service and followed exactly. Failure to route the wires properly may result in drivability problems.

Connect the negative battery cable to the battery terminal.

Checkpoint: Verify all spark plug wires are connected to their numbered or labeled locations and the negative battery cable is securely attached.

Final Checkpoint: Ensure all tools are removed from the engine compartment and all connections are secure before starting the engine.
"""

# %%
#test set 2: instruction with ideal expected output

input="provide the procedure for installation and removal of timing belt cover"

output= """Timing Belt Cover Removal, Adjustment, and Installation

A: REMOVAL

Remove V-belt <Ref. to ME(H4DOTC)-54, REMOVAL, V-belt>
Remove crankshaft pulley <Ref. to ME(H4DOTC)-56, REMOVAL, Crankshaft Pulley>
Remove timing belt cover <Ref. to ME(H4DOTC)-57, REMOVAL, Timing Belt Cover>
Remove timing belt guides (MT model)
Mark timing belt alignment (if marks are faded):
Turn crankshaft using ST 499987500 CRANKSHAFT SOCKET
Align alignment marks on all sprockets with notches
Apply white paint marks on timing belt relative to sprockets
Remove belt idler (A)
Remove timing belt
Pro Tip: Take photos of belt routing before removal to reference during installation
Belt Idler and Automatic Belt Tension Adjuster Removal:
Remove belt idler (B) and (C)
Remove belt idler No. 2
Remove automatic belt tension adjuster assembly
B: INSTALLATION
Automatic Belt Tension Adjuster Preparation:
Warning: Critical tensioner adjustment procedure - follow exactly:
Use only vertical type pressing tool
Apply pressure of 294 N (30 kgf, 66 lb) slowly
Take more than 3 minutes for adjustment
Do not exceed 9,807 N (1,000 kgf, 2,205 lb) pressure
Attach automatic belt tension adjuster to vertical pressing tool
Move adjuster rod down slowly with 294 N (30 kgf, 66 lb) pressure
Insert 2 mm stopper pin when rod aligns with hole
Install automatic belt tension adjuster assembly
Tightening torque: 39 N·m (4.0 kgf-m, 28.9 ft-lb)
Belt Idler Installation:
Install belt idler No. 2
Tightening torque: 39 N·m (4.0 kgf-m, 28.9 ft-lb)
Install belt idler
Tightening torque: 39 N·m (4.0 kgf-m, 28.9 ft-lb)
Critical Timing Belt Installation:
Checkpoint: Verify all sprocket alignment marks before belt installation
Timing Belt Installation:
Warning: Disengagement of more than three timing belt teeth may result in valve and piston interference
Install timing belt following alphabetical sequence shown in ME-00089
Ensure belt rotation direction is correct (follow arrow marks)
Install belt idlers
Tightening torque: 39 N·m (4.0 kgf-m, 28.9 ft-lb)
Checkpoint: Verify all timing marks are still aligned before proceeding
Remove stopper pin from tensioner adjuster
Install timing belt guide (MT model)
Clearance: 1.0±0.5 mm (0.039±0.020 in)
Tightening torque: 10 N·m (1.0 kgf-m, 7.2 ft-lb)
"""

expected_output="""Timing Belt Removal and Adjustment Procedures
Detailed Steps
A: REMOVAL
Timing Belt Cover Removal
Remove V-belt <Ref. to ME(H4DOTC)-54, REMOVAL, V-belt>
Remove crankshaft pulley <Ref. to ME(H4DOTC)-56, REMOVAL, Crankshaft Pulley>
Remove timing belt cover (LH) (A)
Remove timing belt cover (RH) (B)
Remove front timing belt cover (C)

Timing Belt Removal
Remove timing belt cover <Ref. to ME(H4DOTC)-57, REMOVAL, Timing Belt Cover>
Remove timing belt guides (MT model)
Turn crankshaft using ST 499987500 CRANKSHAFT SOCKET and align alignment marks on crankshaft sprocket, intake camshaft sprocket (LH), exhaust camshaft sprocket (LH), intake camshaft sprocket (RH) and exhaust camshaft sprocket (RH) with notches of timing belt cover and cylinder block
Put alignment and/or arrow marks on timing belts using white paint in relation to sprockets:
Z1: 54.5 tooth length
Z2: 51 tooth length
Z3: 28 tooth length
Remove belt idler (A)
Remove timing belt
Belt Idler and Automatic Belt Tension Adjuster Assembly Removal
Remove belt idler (B) and (C)
Remove belt idler No. 2
Remove automatic belt tension adjuster assembly

B: INSTALLATION
Automatic Belt Tension Adjuster Assembly and Belt Idler Installation
Attach automatic belt tension adjuster assembly to vertical pressing tool
Move adjuster rod down slowly with pressure 294 N (30 kgf, 66 lb) until adjuster rod aligns with stopper pin hole in cylinder
Insert 2 mm (0.08 in) dia. stopper pin or hex bar wrench into stopper pin hole and secure adjuster rod
Install automatic belt tension adjuster assembly
Tightening torque: 39 N·m (4.0 kgf-m, 28.9 ft-lb)
Install belt idler No. 2
Tightening torque: 39 N·m (4.0 kgf-m, 28.9 ft-lb)
Install belt idler
Tightening torque: 39 N·m (4.0 kgf-m, 28.9 ft-lb)

Crankshaft and Camshaft Sprocket Alignment
Align mark (A) on crankshaft sprocket with mark on oil pump cover at cylinder block
Align single line mark (A) on exhaust camshaft sprocket (RH) with notch (B) on timing belt cover
Align single line mark (A) on intake camshaft sprocket (RH) with notch (B) on timing belt cover (ensure double lines (C) on intake camshaft and exhaust camshaft sprockets are aligned)
Align single line mark (A) on exhaust camshaft sprocket (LH) with notch (B) on timing belt cover by turning sprocket counterclockwise
Align single line mark (A) on intake camshaft sprocket (LH) with notch (B) on timing belt cover by turning sprocket clockwise (ensure double lines (C) are aligned)
Ensure camshaft and crankshaft sprockets are positioned properly

Timing Belt Installation
Align alignment mark on timing belt with marks on sprockets in alphabetical order
Position timing belt properly while aligning marks
Install belt idlers
Tightening torque: 39 N·m (4.0 kgf-m, 28.9 ft-lb)
Remove stopper pin from tensioner adjuster after ensuring marks are aligned

Install timing belt guide (MT model):
Temporarily tighten bolts
Check and adjust clearance between timing belt and timing belt guide: 1.0±0.5 mm (0.039±0.020 in)
Tighten bolts: 10 N·m (1.0 kgf-m, 7.2 ft-lb) and 6.4 N·m (0.65 kgf-m, 4.7 ft-lb)

Final Assembly
Install timing belt cover <Ref. to ME(H4DOTC)-57, INSTALLATION, Timing Belt Cover>
Tightening torque: 5 N·m (0.5 kgf-m, 3.6 ft-lb)
Install crankshaft pulley <Ref. to ME(H4DOTC)-56, INSTALLATION, Crankshaft Pulley>
Install V-belt <Ref. to ME(H4DOTC)-54, INSTALLATION, V-belt>

C: INSPECTION
Timing Belt Inspection
Check timing belt teeth for breaks, cracks, and wear
Check condition of back side of belt for cracks
Ensure bending radius: 60 mm (2.36 in) or more
Automatic Belt Tension Adjuster Inspection
Check oil seals for leaks and rod ends for abnormal wear or scratches
Check adjuster rod does not move when pressure 294 N (30 kgf, 66 lb) is applied
Measure rod extension: 5.7±0.5 mm (0.224±0.020 in)
Belt Tension Pulley and Belt Idler Inspection
Check mating surfaces for abnormal wear or scratches
Check for smooth rotation and grease leakage
"""

# %%
#test set 2.1: same as set 2, only that now using expected_output as the output to see if there is any improvement to score
input="provide the procedure for installation and removal of timing belt cover"

output="""Timing Belt Removal and Adjustment Procedures
Detailed Steps
A: REMOVAL
Timing Belt Cover Removal
Remove V-belt <Ref. to ME(H4DOTC)-54, REMOVAL, V-belt>
Remove crankshaft pulley <Ref. to ME(H4DOTC)-56, REMOVAL, Crankshaft Pulley>
Remove timing belt cover (LH) (A)
Remove timing belt cover (RH) (B)
Remove front timing belt cover (C)

Timing Belt Removal
Remove timing belt cover <Ref. to ME(H4DOTC)-57, REMOVAL, Timing Belt Cover>
Remove timing belt guides (MT model)
Turn crankshaft using ST 499987500 CRANKSHAFT SOCKET and align alignment marks on crankshaft sprocket, intake camshaft sprocket (LH), exhaust camshaft sprocket (LH), intake camshaft sprocket (RH) and exhaust camshaft sprocket (RH) with notches of timing belt cover and cylinder block
Put alignment and/or arrow marks on timing belts using white paint in relation to sprockets:
Z1: 54.5 tooth length
Z2: 51 tooth length
Z3: 28 tooth length
Remove belt idler (A)
Remove timing belt
Belt Idler and Automatic Belt Tension Adjuster Assembly Removal
Remove belt idler (B) and (C)
Remove belt idler No. 2
Remove automatic belt tension adjuster assembly

B: INSTALLATION
Automatic Belt Tension Adjuster Assembly and Belt Idler Installation
Attach automatic belt tension adjuster assembly to vertical pressing tool
Move adjuster rod down slowly with pressure 294 N (30 kgf, 66 lb) until adjuster rod aligns with stopper pin hole in cylinder
Insert 2 mm (0.08 in) dia. stopper pin or hex bar wrench into stopper pin hole and secure adjuster rod
Install automatic belt tension adjuster assembly
Tightening torque: 39 N·m (4.0 kgf-m, 28.9 ft-lb)
Install belt idler No. 2
Tightening torque: 39 N·m (4.0 kgf-m, 28.9 ft-lb)
Install belt idler
Tightening torque: 39 N·m (4.0 kgf-m, 28.9 ft-lb)

Crankshaft and Camshaft Sprocket Alignment
Align mark (A) on crankshaft sprocket with mark on oil pump cover at cylinder block
Align single line mark (A) on exhaust camshaft sprocket (RH) with notch (B) on timing belt cover
Align single line mark (A) on intake camshaft sprocket (RH) with notch (B) on timing belt cover (ensure double lines (C) on intake camshaft and exhaust camshaft sprockets are aligned)
Align single line mark (A) on exhaust camshaft sprocket (LH) with notch (B) on timing belt cover by turning sprocket counterclockwise
Align single line mark (A) on intake camshaft sprocket (LH) with notch (B) on timing belt cover by turning sprocket clockwise (ensure double lines (C) are aligned)
Ensure camshaft and crankshaft sprockets are positioned properly

Timing Belt Installation
Align alignment mark on timing belt with marks on sprockets in alphabetical order
Position timing belt properly while aligning marks
Install belt idlers
Tightening torque: 39 N·m (4.0 kgf-m, 28.9 ft-lb)
Remove stopper pin from tensioner adjuster after ensuring marks are aligned

Install timing belt guide (MT model):
Temporarily tighten bolts
Check and adjust clearance between timing belt and timing belt guide: 1.0±0.5 mm (0.039±0.020 in)
Tighten bolts: 10 N·m (1.0 kgf-m, 7.2 ft-lb) and 6.4 N·m (0.65 kgf-m, 4.7 ft-lb)

Final Assembly
Install timing belt cover <Ref. to ME(H4DOTC)-57, INSTALLATION, Timing Belt Cover>
Tightening torque: 5 N·m (0.5 kgf-m, 3.6 ft-lb)
Install crankshaft pulley <Ref. to ME(H4DOTC)-56, INSTALLATION, Crankshaft Pulley>
Install V-belt <Ref. to ME(H4DOTC)-54, INSTALLATION, V-belt>

C: INSPECTION
Timing Belt Inspection
Check timing belt teeth for breaks, cracks, and wear
Check condition of back side of belt for cracks
Ensure bending radius: 60 mm (2.36 in) or more
Automatic Belt Tension Adjuster Inspection
Check oil seals for leaks and rod ends for abnormal wear or scratches
Check adjuster rod does not move when pressure 294 N (30 kgf, 66 lb) is applied
Measure rod extension: 5.7±0.5 mm (0.224±0.020 in)
Belt Tension Pulley and Belt Idler Inspection
Check mating surfaces for abnormal wear or scratches
Check for smooth rotation and grease leakage
"""

# %%
#test set 3: simple instructions, modified upstream prompt so to improve scores in all criteria
#result01:[0.785, 0.851, 0.744, 0.856, 0.968]
#result02:[0.987, 0.852, 0.988, 0.95, 1.0]
input="provide the procedure for alternator belt adjustment"
output="""
Alternator Belt: Removal, Adjustment, and Installation

Step-by-step Instruction
A. Safety Preparation and Electrical Shutdown
Turn start switch to OFF position

Turn ignition switch (if equipped) to OFF position and remove key

Remove all electrical loads

Warning: Never proceed with belt work while engine is running or electrical systems are active

Checkpoint: Verify start switch is OFF, ignition switch is OFF, and key is removed

Disconnect negative battery terminal at battery that goes to start switch

Ensure cable cannot contact terminal

Warning: When four 12 volt batteries are involved, disconnect negative side of two batteries

Checkpoint: Cable is completely separated from terminal and secured away

Tape leads to help prevent accidental starting

Warning: Failure to tape leads may result in accidental engine start during maintenance

Checkpoint: All disconnected leads are securely taped

B. Belt Inspection and Assessment
Inspect alternator belt for wear and for cracking

Look for: Visible cracks, fraying, worn edges, glazing, oil contamination

Replace belts if belts are not in good condition

Checkpoint: Belt condition is assessed - proceed with replacement if wear or cracking is found

Check belt tension according to Service Manual "Specifications"

Warning: Slippage of loose belts can reduce efficiency of driven components

Warning: Vibration of loose belts can cause unnecessary wear on belts, pulleys, bearings

Warning: If belts are too tight, unnecessary stress is placed on components, reducing service life

Checkpoint: Current belt tension is noted for reference

C. Alternator Belt Removal
Remove belt guard

Checkpoint: Belt guard is completely free and safely stored for reinstallation

Loosen mounting bolts (1) and adjusting bolt (2)

Specification: Loosen sufficiently to allow assembly movement (do not completely remove)

Checkpoint: Bolts are loose enough to permit belt tension adjustment

Move assembly to decrease belt tension for removal

Checkpoint: Belt tension is reduced sufficiently for safe belt removal

Remove alternator belt from pulleys

Checkpoint: Belt is completely free from all pulley contact

D. Belt Installation and Adjustment
Install new or serviced alternator belt onto pulleys

Warning: For multiple drive belt applications, replace belts in matched sets

Warning: Replacing one belt of matched set will cause new belt to carry more load because older belts are stretched

Warning: Additional load on new belt could cause new belt to fail

Checkpoint: Belt is properly seated on all pulleys with correct routing

Move assembly to increase belt tension to specification

Specification: Adjust according to Service Manual "Specifications"

Checkpoint: Belt tension meets specified requirements

Tighten adjusting bolt (2)

Specification: Hand-tighten securely (no specific torque value provided in source)

Checkpoint: Adjusting bolt is secure and maintains belt tension

Tighten mounting bolts (1)

Specification: Hand-tighten securely (no specific torque value provided in source)

Checkpoint: All mounting bolts are secure

Reinstall belt guard

Checkpoint: Belt guard is properly secured with all fasteners tight

E. Post-Installation Verification
Check drive belt tension after 30 minutes of engine operation at rated rpm (if new drive belts installed)

Specification: 30 minutes at rated rpm

Warning: This verification is mandatory for new belt installations

Checkpoint: Belt maintains proper tension after break-in period

F. System Restoration
Remove tape from battery leads

Checkpoint: All tape is removed and disposed of properly

Reconnect negative battery terminal following reverse steps

Connect cable securely to battery terminal

Warning: For four 12 volt battery systems, reconnect both previously disconnected batteries

Checkpoint: Battery connection is tight and secure

Restore all electrical loads and ignition system

Return ignition switch to normal position

Checkpoint: All electrical systems function normally

Test engine operation

Start engine and observe belt operation

Listen for unusual noises or vibrations

Checkpoint: Engine starts normally and alternator belt operates without slippage, noise, or vibration

"""

# %%
#test set 4: simple instruction
input="provide the procedure for fan drive belt adjustment"
output="""Caterpillar Fan Drive Belt Adjustment
Detailed Steps
Remove belt guard
Loosen mounting bolt for pulley
Loosen adjusting nut for pulley
Move pulley to adjust belt tension
Tighten adjusting nut
Tighten mounting bolt
Reinstall belt guard
Check drive belt tension again after 30 minutes of engine operation at rated rpm (if new belts installed). This allows the new belt to settle into the drive belt.
"""

# %%
from deepeval.metrics import GEval
from deepeval.test_case import LLMTestCaseParams, LLMTestCase
from deepeval.metrics.g_eval import Rubric

# %% [markdown]
# format criteria to suit 2 different evaluaton approaches

# %%
criteria_intro="""
      You are a maintenance knowledge expert in the engineering industry. Evaluate the output and assign a score from 0–10 for each criterion. Justify your score and make recommendations for improvements.
      """
criteria_set=[
      "Step-by-Step Accuracy: output should include all procedural steps from the source. All steps are in the correct order. There should not be any missing, added or modified steps that may result in user error or damage.",
      "Terminology Fidelity: technical terms from source should be preserved. use domain-specific vocabulary.",
      "Handling of Warnings and Cautions: safety warnings and cautions should be clearly flagged. risk-related statements should be placed near the relevant steps.",
      "Precision in instructions: where it applies, instructions should provide user clear numerical measure of the required specifications. for example, a procedure involving inspection should indicate exactly what to look out for (e.g. rust, dirt, damage etc). ",
      "Closed Loop Procedural: procedural instructions should result in a closed loop. for example, a procedure involving the removal of an component should eventually be closed with the reinstallation of the component."
]

criteria_complete="""
  Step-by-Step Accuracy: output should include all procedural steps from the source. All steps are in the correct order. There should not be any missing, added or modified steps that may result in user error or damage.
  Terminology Fidelity: technical terms from source should be preserved. use domain-specific vocabulary.
  Handling of Warnings and Cautions: safety warnings and cautions should be clearly flagged. risk-related statements should be placed near the relevant steps.
  Precision in instructions: where it applies, instructions should provide user clear numerical measure of the required specifications. for example, a procedure involving inspection should indicate exactly what to look out for (e.g. rust, dirt, damage etc).
  Closed Loop Procedural: procedural instructions should result in a closed loop. for example, a procedure involving the removal of an component should eventually be closed with the reinstallation of the component.
  Thereafter recommend improvements for the worst-scoring criteria.
  """

rubric_set1=[
    Rubric(score_range=(0,1), expected_outcome="totally not meeting criteria."),
    Rubric(score_range=(2,3), expected_outcome="barely meeting criteria only in a few parts of output."),
    Rubric(score_range=(4,5), expected_outcome="barely meeting criteria most parts of output."),
    Rubric(score_range=(6,7), expected_outcome="mostly meeting criteria but missing a lot of minor details."),
    Rubric(score_range=(8,9), expected_outcome="mostly meeting criteria but missing a few minor details."),
    Rubric(score_range=(10,10), expected_outcome="perfectly meeting criteria."),
    ]

# %% [markdown]
# Essentially, each loop runs only 1 criteria. the combined results are tabulated in as combined results.

# %%
#loop GEval to provide evaluation score for individual criterion

results_score=[]
results_reason=[]

for criteria in criteria_set:
  proaccuracy_metric = GEval(
    name="Procedure Extraction Evaluator",
    criteria=criteria_intro+criteria,
    #evaluation_params=[LLMTestCaseParams.ACTUAL_OUTPUT, LLMTestCaseParams.EXPECTED_OUTPUT],
    evaluation_params=[LLMTestCaseParams.INPUT, LLMTestCaseParams.ACTUAL_OUTPUT],
    rubric=rubric_set1,

    verbose_mode=False,
    threshold=0.4
    )
  test_case = LLMTestCase(input, output)
  #test_case = LLMTestCase(input, output, expected_output)

  proaccuracy_metric.measure(test_case)

  #Print each results
  #print(proaccuracy_metric.score, proaccuracy_metric.reason)

  #Append score and reason as a tuple
  results_score.append(proaccuracy_metric.score)
  results_reason.append(proaccuracy_metric.reason)

#merge all results at a list
criteria_names = ["Step-by-Step Accuracy","Terminology Fidelity","Warning/Caution Handling","Instruction Precision","Close-Loop Procedure"]
combined_results = list(zip(results_score, results_reason))
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
combined_results
# Out:
# [(0.6877151520527002,
#   'The output includes most procedural steps for spark plug installation and removal, but it introduces alternative processes and additional precautions not specified in the input. The sequence is mostly correct, but the presence of extra steps and details could lead to confusion.'),
#  (0.8714493024138692,
#   "The output maintains most technical terms such as 'spark plugs', 'ignition switch', 'spark plug wires', and 'torque'. However, it introduces terms like 'J 39358' without context and omits some specific procedural details from the input, such as the exact sequence of installation and removal steps."),
#  (0.8125987201532038,
# ...

# %%
#answer preparation

#rounded scores
results_score_rounded = [round(score, ndigits=3) for score in results_score]

#average score
result_score_avg = sum(results_score_rounded) / len(results_score_rounded)

print(results_score_rounded, result_score_avg)
# Out:
# [0.932, 0.858, 0.935, 0.911, 0.995] 0.9262

# %%
#run GEval using all the criteria as a set, generating only a single score. Meant as a check
proaccuracy_metric = GEval(
    name="Procedure Extraction Evaluator",
    criteria=criteria_intro+criteria_complete,

    #evaluation_params=[LLMTestCaseParams.ACTUAL_OUTPUT, LLMTestCaseParams.EXPECTED_OUTPUT],
    evaluation_params=[LLMTestCaseParams.INPUT, LLMTestCaseParams.ACTUAL_OUTPUT],

    rubric=rubric_set1,
    #verbose_mode="everything",
    verbose_mode="false",
    threshold=0.1,
)

test_case = LLMTestCase(input, output)
#test_case = LLMTestCase(input, output, expected_output)

proaccuracy_metric.measure(test_case)

print(proaccuracy_metric.score, proaccuracy_metric.reason)
# Out:
# Output()
# **************************************************
# Procedure Extraction Evaluator (GEval) Verbose Logs
# **************************************************
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Criteria:
#
#       You are a maintenance knowledge expert in the engineering industry. Evaluate the output and assign a score
# from 0–10 for each criterion. Justify your score and make recommendations for improvements.
#
#   Step-by-Step Accuracy: output should include all procedural steps from the source. All steps are in the correct
# order. There should not be any missing, added or modified steps that may result in user error or damage.
#   Terminology Fidelity: technical terms from source should be preserved. use domain-specific vocabulary.
#   Handling of Warnings and Cautions: safety warnings and cautions should be clearly flagged. risk-related
# ...
